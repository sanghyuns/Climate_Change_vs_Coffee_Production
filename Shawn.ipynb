# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Ethiopia Production

# %%
prod_df = pd.read_csv('./data/production.csv')

# %%
prod_df.shape
# Out:
# (56, 32)

# %%
prod_df = prod_df.T

# %%
eth_prod = pd.DataFrame(prod_df)

# %%
header = eth_prod.iloc[0]
eth_prod = eth_prod[1:]
eth_prod.columns = header

# %%
eth_prod.head()
# Out:
# Unnamed: 0      5                                 6           7        8   \
# Crop year   Angola  Bolivia (Plurinational State of)      Brazil  Burundi
# 1990/91     50.345                           122.777  27285.6286  487.393
# 1991/92     79.331                           103.536  27293.4934  667.199
# 1992/93      77.52                           120.235  34603.3542  620.238
# 1993/94     32.608                            50.823  28166.9786  393.354
#
# Unnamed: 0        9          10          11       12                13  \
# Crop year    Ecuador  Indonesia  Madagascar   Malawi  Papua New Guinea
# 1990/91     1503.815   7441.383     982.447  104.628           962.841
# 1991/92     2123.824   8493.196     932.513  124.286           746.816
# 1992/93      1185.48   5569.478    1121.684  137.161           900.111
# 1993/94     2069.007   6743.288     441.859   62.111          1019.481
#
# Unnamed: 0        14  ...            55         56        57       58  \
# Crop year   Paraguay  ...  Sierra Leone  Sri Lanka  Thailand     Togo
# 1990/91      130.627  ...        42.783      95.87   757.017  161.308
# 1991/92       79.653  ...        54.379     81.549  1468.936  432.652
# 1992/93       54.291  ...        39.084     53.181  1254.945   85.648
# 1993/94      66.5275  ...        37.451      53.79  1275.201  194.939
#
# Unnamed: 0                 59        60         61        62     63  \
# Crop year   Trinidad & Tobago    Uganda  Venezuela  Viet Nam  Yemen
# 1990/91                14.581  1955.009   1122.477  1310.288    0.0
# 1991/92                17.792  2088.001    940.704  1437.848    0.0
# 1992/93                14.328  2185.074   1215.298  2340.447    0.0
# 1993/94                16.079  3141.706   1332.881  3020.216    0.0
#
# Unnamed: 0           65
# Crop year         Total
# 1990/91      93230.0596
# 1991/92     101266.6844
# 1992/93      98524.0942
# 1993/94      91761.0531
#
# [5 rows x 56 columns]

# %%
#setting column name as the country names
eth_prod.columns = eth_prod.iloc[0]

# %%
# dropping first row
eth_prod = eth_prod.iloc[1:]

# %%
eth_prod = eth_prod[['Ethiopia']]

# %%
eth_prod.head()
# Out:
# Crop year  Ethiopia
# 1990/91    2909.451
# 1991/92    2924.664
# 1992/93    1825.171
# 1993/94    2967.004
# 1994/95     2762.73

# %% [markdown]
# ## Retail Prices

# %%
retail_prices = pd.read_excel('./data/3b - retail_prices.xlsx')

# %%
retail_prices.head()
# Out:
#    Year     Austria     Belgium     Bulgaria     Cyprus     Czechia  \
# 0  1990        4.90        3.27          NaN       2.83         NaN
# 1  1991        4.57        2.92          NaN       2.80         NaN
# 2  1992        4.99        3.05          NaN       2.87         NaN
# 3  1993        4.97        2.78          NaN       2.60         NaN
# 4  1994        4.58        3.42          NaN       3.18         NaN
#
#       Denmark     Finland     France     Germany  ...     Slovakia  \
# 0        3.81        2.98       3.73        3.99  ...          NaN
# 1        3.67        2.72       3.43        3.84  ...          NaN
# 2        3.79        2.46       2.31        4.00  ...          NaN
# 3        3.48        1.94       2.03        3.62  ...          NaN
# 4        4.45        2.73       2.40        4.18  ...          NaN
#
#       Slovenia     Spain     Sweden  Japan  Norway  Russian Federation  \
# 0          NaN      3.62       3.43  10.26    3.31                 NaN
# 1          NaN      3.50       3.29  11.88    3.16                 NaN
# 2          NaN      3.50       3.11  12.62    3.12                 NaN
# 3          NaN      2.79       2.65  14.57    2.46                 NaN
# 4          NaN      2.76       3.79  14.69    3.29                 NaN
#
#    Switzerland  United Kingdom 1  United States of America
# 0         4.83             10.55                      2.97
# 1         4.36             10.41                      2.81
# 2         4.52             10.09                      2.58
# 3         4.27              8.44                      2.47
# 4         4.50             11.36                      3.40
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Ethiopia Temp

# %%
temp_df = pd.read_csv('data/FAOSTAT_data_1-10-2022.csv')

# %%
ethiopia_temp_change = temp_df[temp_df.Area == 'Ethiopia']

# %%
ethiopia_temp_change.columns = [col.lower().strip().replace(' ', '_')
    for col in ethiopia_temp_change.columns]

# %%
ethiopia_temp_change = ethiopia_temp_change[ethiopia_temp_change['months']=='Meteorological year'].sort_values(by=['months', 'year'], ascending= False)

# %%
e_temp_change = ethiopia_temp_change[['year','value']].iloc[::-1]

# %%
e_temp_change.rename(columns={'value':'e_temp_change'}, inplace = True)

# %%
e_temp_change.head()
# Out:
#        year  e_temp_change
# 70182  1993          0.244
# 70183  1994          0.599
# 70184  1995          0.815
# 70185  1996          0.775
# 70186  1997          0.713

# %% [markdown]
# ## Ethiopia Exports

# %%
e_export = pd.read_excel('./data/2a - Exports - calendar year.xlsx')

# %%
e_export.dropna(inplace = True)

# %%
e_export = e_export.T

# %%
new_header = e_export.iloc[0]
e_export = e_export[1:] 
e_export.columns = new_header

# %%
e_export.columns = [col.lower().strip().replace(' ','_') 
                         for col in e_export.columns]

# %%
e_export = e_export[['calendar_years','ethiopia']]

# %%
e_export.rename(columns={'calendar_years':'year', 'ethiopia':'e_export'}, inplace = True)

# %%
e_export.head()
# Out:
#               year  e_export
# Unnamed: 1  1990.0  1074.101
# Unnamed: 2  1991.0   841.329
# Unnamed: 3  1992.0   734.461
# Unnamed: 4  1993.0  1166.778
# Unnamed: 5  1994.0  1475.325

# %% [markdown]
# ## Ethiopia Domestic Consumption (Disappearance)

# %%
consumption = pd.read_excel('./data/1b - Domestic consumption.xlsx')
# Out:
# /Users/sangs/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
consumption = consumption.T

# %%
new_header = consumption.iloc[0]
consumption = consumption[1:] 
consumption.columns = new_header

# %%
consumption = consumption.drop(consumption.index[:1])

# %%
consumption.head()
# Out:
# Domestic consumption by all exporting countries In thousand 60kg bags  NaN  \
# Unnamed: 2                                                        NaN  NaN
# Unnamed: 3                                                        NaN  NaN
# Unnamed: 4                                                        NaN  NaN
# Unnamed: 5                                                        NaN  NaN
# Unnamed: 6                                                        NaN  NaN
#
# Domestic consumption by all exporting countries Crop year  NaN April group  \
# Unnamed: 2                                        1990/91  NaN       10408
# Unnamed: 3                                        1991/92  NaN     10707.6
# Unnamed: 4                                        1992/93  NaN     11212.2
# Unnamed: 5                                        1993/94  NaN   11452.743
# Unnamed: 6                                        1994/95  NaN   11506.499
#
# Domestic consumption by all exporting countries Angola  \
# Unnamed: 2                                          20
# Unnamed: 3                                          30
# Unnamed: 4                                          35
# Unnamed: 5                                          20
# Unnamed: 6                                          25
#
# Domestic consumption by all exporting countries Bolivia (Plurinational State of)  \
# Unnamed: 2                                                                    25
# Unnamed: 3                                                                    27
# Unnamed: 4                                                                  27.5
# Unnamed: 5                                                                  28.5
# Unnamed: 6                                                                  29.5
#
# Domestic consumption by all exporting countries Brazil Burundi Ecuador  ...  \
# Unnamed: 2                                        8200       2     350  ...
# Unnamed: 3                                        8500     1.6     350  ...
# Unnamed: 4                                        8900     1.7     350  ...
# Unnamed: 5                                        9100    1.91     350  ...
# Unnamed: 6                                        9300       2     350  ...
#
# Domestic consumption by all exporting countries Thailand Togo  \
# Unnamed: 2                                           188    1
# Unnamed: 3                                           220    1
# Unnamed: 4                                           233    1
# Unnamed: 5                                           250    1
# Unnamed: 6                                           283    1
#
# Domestic consumption by all exporting countries Trinidad & Tobago Uganda  \
# Unnamed: 2                                                      8     70
# Unnamed: 3                                                   11.5     75
# Unnamed: 4                                                     10     75
# Unnamed: 5                                                     10     75
# Unnamed: 6                                                     14     80
#
# Domestic consumption by all exporting countries Venezuela Viet Nam Yemen  NaN  \
# Unnamed: 2                                         782.39      150     0  NaN
# Unnamed: 3                                         815.48      230     0  NaN
# Unnamed: 4                                         849.97      250     0  NaN
# Unnamed: 5                                         885.93      267     0  NaN
# Unnamed: 6                                          923.4      267     0  NaN
#
# Domestic consumption by all exporting countries      Total  \
# Unnamed: 2                                       19509.211
# Unnamed: 3                                       20228.097
# Unnamed: 4                                       20951.452
# Unnamed: 5                                       21097.906
# Unnamed: 6                                       21360.166
#
# Domestic consumption by all exporting countries © International Coffee Organization
# Unnamed: 2                                                                      NaN
# Unnamed: 3                                                                      NaN
# Unnamed: 4                                                                      NaN
# Unnamed: 5                                                                      NaN
# Unnamed: 6                                                                      NaN
#
# [5 rows x 67 columns]

# %%
consumption = consumption.drop(consumption.columns[:2], axis = 1)

# %%
consumption = consumption[['Crop year','Ethiopia']]

# %%
consumption.columns = [col.lower().strip().replace(' ','_') 
                         for col in consumption.columns]

# %%
consumption.head()
# Out:
#             crop_year ethiopia
# Unnamed: 2    1990/91     1200
# Unnamed: 3    1991/92     1264
# Unnamed: 4    1992/93     1331
# Unnamed: 5    1993/94     1402
# Unnamed: 6    1994/95     1476
# Unnamed: 7    1995/96     1555
# Unnamed: 8    1996/97     1637
# Unnamed: 9    1997/98     1724
# Unnamed: 10   1998/99     1816
# Unnamed: 11   1999/00     1912
# Unnamed: 12   2000/01     2014
# Unnamed: 13   2001/02     2121
# Unnamed: 14   2002/03     2234
# Unnamed: 15   2003/04     2353
# Unnamed: 16   2004/05     2478
# Unnamed: 17   2005/06     2609
# Unnamed: 18   2006/07     2748
# Unnamed: 19   2007/08     2894
# Unnamed: 20   2008/09     3048
# Unnamed: 21   2009/10     3109
# Unnamed: 22   2010/11     3171
# Unnamed: 23   2011/12     3235
# Unnamed: 24   2012/13     3299
# Unnamed: 25   2013/14     3365
# Unnamed: 26   2014/15     3433
# Unnamed: 27   2015/16     3501
# Unnamed: 28   2016/17     3571
# Unnamed: 29   2017/18     3643
# Unnamed: 30   2018/19     3685
# Unnamed: 31   2019/20     3781

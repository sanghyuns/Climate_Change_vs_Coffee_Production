# %%
import pandas as pd

# %%
prod_df = pd.read_csv('./production.csv')

# %%
prod_df.shape
# Out:
# (56, 32)

# %%
prod_df.describe()
# Out:
#        Unnamed: 0       1990/91        1991/92       1992/93       1993/94  \
# count   56.000000     56.000000      56.000000     56.000000     56.000000
# mean    35.267857   3329.644986    3616.667300   3518.717650   3277.180468
# std     17.837133  12915.596615   13998.084651  13856.532653  12721.697262
# min      5.000000      0.000000       0.000000      0.000000      0.000000
# 25%     20.250000     41.551000      70.824250     46.432500     36.660000
# 50%     36.500000    474.235500     473.591000    523.574500    442.742000
# 75%     50.250000   1571.042500    1816.461250   1777.757500   1889.136000
# max     65.000000  93230.059600  101266.684400  98524.094200  91761.053100
#
#             1994/95       1995/96        1996/97       1997/98        1998/99  \
# count     56.000000     56.000000      56.000000     56.000000      56.000000
# mean    3332.634618   3118.602468    3689.567004   3567.398611    3888.057364
# ...

# %%
prod_df.head()
# Out:
#    Unnamed: 0                         Crop year     1990/91     1991/92  \
# 0           5                            Angola     50.3450     79.3310
# 1           6  Bolivia (Plurinational State of)    122.7770    103.5360
# 2           7                            Brazil  27285.6286  27293.4934
# 3           8                           Burundi    487.3930    667.1990
# 4           9                           Ecuador   1503.8150   2123.8240
#
#       1992/93     1993/94    1994/95     1995/96    1996/97    1997/98  ...  \
# 0     77.5200     32.6080     76.802     62.1090     70.925     64.330  ...
# 1    120.2350     50.8230    116.944    142.4850    124.579    140.719  ...
# 2  34603.3542  28166.9786  28192.047  18060.2022  29196.743  26148.004  ...
# 3    620.2380    393.3540    664.143    433.9800    400.969    249.785  ...
# 4   1185.4800   2069.0070   2375.766   1888.2330   1992.914   1190.663  ...
#
# ...
